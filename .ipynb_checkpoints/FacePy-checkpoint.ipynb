# %%
##test code

import numpy as np
import cv2

cap = cv2.VideoCapture(0)

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.avi',fourcc, 20.0, (640,480))

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:
        frame = cv2.flip(frame,0)

        # write the flipped frame
        out.write(frame)

        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release everything if job is finished
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
###
#顔を撮影して50*50にリサイズし保存する
###

import cv2
import glob
import time
import sys
import numpy as np
from datetime import datetime

#コンピュータに接続されているカメラが1台なら0
cap = cv2.VideoCapture(0)

#顔を判定するために使う
cascade_path = 'opencv-master/haarcascades/haarcascade_frontalface_alt.xml'
cascade = cv2.CascadeClassifier(cascade_path)

dir = 'img/'

#写真を撮る枚数。多ければ多いほどいいが重くなる
num = 500

label = str(input("あなたを判別するための名前を半角英数字4文字で入力してください ex.slf:"))
file_number = len(glob.glob('img/*'))
count = 0

if not len(label) == 4:
    print("半角英数字4文字で入力してください")
    sys.exit()

while True:
    if count < num:
        time.sleep(0.01)
        print("あと{}枚です".format(num-count))
        datenow = datetime.now()
        r, img = cap.read()
        #imgUMat = np.float32(img)
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = cascade.detectMultiScale(img_gray, scaleFactor = 1.1, minNeighbors = 1, minSize = (100, 100))


        #顔を判定した場合
        if len(faces) > 0:
            for face in faces:
                #□の左上のx座標
                x = face[0]
                #同じくy座標
                y = face[1]
                #□の長さ
                width = face[2]
                #同じく高さ
                height = face[3]
                #リサイズ
                roi = cv2.resize(img[y:y + height, x:x + width], (50, 50), interpolation = cv2.INTER_LINEAR)
                cv2.imwrite(dir + label+ "_" + str(count) + '.jpg', roi)
        
        
        count = len(glob.glob('img/*')) - file_number
    
    else:
        break
    
cap.release()
# Out:
# あなたを判別するための名前を半角英数字4文字で入力してください ex.slf:huku
# あと500枚です
# あと499枚です
# あと498枚です
# あと497枚です
# あと496枚です
# あと495枚です
# あと494枚です
# あと493枚です
# あと492枚です
# あと491枚です
# あと490枚です
# あと489枚です
# あと488枚です
# あと487枚です
# あと486枚です
# あと485枚です
# あと484枚です
# あと483枚です
# あと482枚です
# あと481枚です
# あと480枚です
# あと479枚です
# あと478枚です
# あと477枚です
# あと476枚です
# あと475枚です
# あと474枚です
# あと473枚です
# あと472枚です
# あと471枚です
# あと470枚です
# あと469枚です
# あと468枚です
# あと467枚です
# あと466枚です
# あと465枚です
# あと464枚です
# あと463枚です
# あと462枚です
# あと461枚です
# あと460枚です
# あと459枚です
# あと458枚です
# あと457枚です
# あと456枚です
# あと455枚です
# あと454枚です
# あと453枚です
# あと452枚です
# あと451枚です
# あと450枚です
# あと449枚です
# あと448枚です
# あと447枚です
# あと446枚です
# あと445枚です
# あと444枚です
# あと443枚です
# あと442枚です
# あと441枚です
# あと440枚です
# あと439枚です
# あと438枚です
# あと437枚です
# あと436枚です
# あと435枚です
# あと434枚です
# あと433枚です
# あと432枚です
# あと431枚です
# あと430枚です
# あと429枚です
# あと428枚です
# あと427枚です
# あと426枚です
# あと425枚です
# あと424枚です
# あと423枚です
# あと422枚です
# あと421枚です
# あと420枚です
# あと419枚です
# あと418枚です
# あと417枚です
# あと416枚です
# あと415枚です
# あと414枚です
# あと413枚です
# あと412枚です
# あと411枚です
# あと410枚です
# あと409枚です
# あと408枚です
# あと407枚です
# あと406枚です
# あと405枚です
# あと404枚です
# あと403枚です
# あと402枚です
# あと401枚です
# あと400枚です
# あと399枚です
# あと398枚です
# あと397枚です
# あと396枚です
# あと395枚です
# あと394枚です
# あと393枚です
# あと392枚です
# あと391枚です
# あと390枚です
# あと389枚です
# あと388枚です
# あと387枚です
# あと386枚です
# あと385枚です
# あと384枚です
# あと383枚です
# あと382枚です
# あと381枚です
# あと380枚です
# あと379枚です
# あと378枚です
# あと377枚です
# あと376枚です
# あと375枚です
# あと374枚です
# あと373枚です
# あと372枚です
# あと371枚です
# あと370枚です
# あと369枚です
# あと368枚です
# あと367枚です
# あと366枚です
# あと365枚です
# あと364枚です
# あと363枚です
# あと362枚です
# あと361枚です
# あと360枚です
# あと359枚です
# あと358枚です
# あと357枚です
# あと356枚です
# あと355枚です
# あと354枚です
# あと353枚です
# あと352枚です
# あと351枚です
# あと350枚です
# あと349枚です
# あと348枚です
# あと347枚です
# あと346枚です
# あと345枚です
# あと344枚です
# あと343枚です
# あと342枚です
# あと341枚です
# あと340枚です
# あと339枚です
# あと338枚です
# あと337枚です
# あと336枚です
# あと335枚です
# あと334枚です
# あと333枚です
# あと332枚です
# あと331枚です
# あと330枚です
# あと329枚です
# あと328枚です
# あと327枚です
# あと326枚です
# あと325枚です
# あと324枚です
# あと323枚です
# あと322枚です
# あと321枚です
# あと320枚です
# あと319枚です
# あと318枚です
# あと317枚です
# あと316枚です
# あと315枚です
# あと314枚です
# あと313枚です
# あと312枚です
# あと311枚です
# あと310枚です
# あと309枚です
# あと308枚です
# あと307枚です
# あと306枚です
# あと305枚です
# あと304枚です
# あと303枚です
# あと302枚です
# あと301枚です
# あと300枚です
# あと299枚です
# あと298枚です
# あと297枚です
# あと296枚です
# あと295枚です
# あと294枚です
# あと293枚です
# あと292枚です
# あと291枚です
# あと290枚です
# あと289枚です
# あと288枚です
# あと287枚です
# あと286枚です
# あと285枚です
# あと284枚です
# あと283枚です
# あと282枚です
# あと281枚です
# あと280枚です
# あと279枚です
# あと278枚です
# あと277枚です
# あと276枚です
# あと275枚です
# あと274枚です
# あと273枚です
# あと272枚です
# あと271枚です
# あと270枚です
# あと269枚です
# あと268枚です
# あと267枚です
# あと266枚です
# あと265枚です
# あと264枚です
# あと263枚です
# あと262枚です
# あと261枚です
# あと260枚です
# あと259枚です
# あと258枚です
# あと257枚です
# あと256枚です
# あと255枚です
# あと254枚です
# あと253枚です
# あと252枚です
# あと251枚です
# あと250枚です
# あと249枚です
# あと248枚です
# あと247枚です
# あと246枚です
# あと245枚です
# あと244枚です
# あと243枚です
# あと242枚です
# あと241枚です
# あと240枚です
# あと239枚です
# あと238枚です
# あと237枚です
# あと236枚です
# あと235枚です
# あと234枚です
# あと233枚です
# あと232枚です
# あと231枚です
# あと230枚です
# あと229枚です
# あと228枚です
# あと227枚です
# あと226枚です
# あと225枚です
# あと224枚です
# あと223枚です
# あと222枚です
# あと221枚です
# あと220枚です
# あと219枚です
# あと218枚です
# あと217枚です
# あと216枚です
# あと215枚です
# あと214枚です
# あと213枚です
# あと212枚です
# あと211枚です
# あと210枚です
# あと209枚です
# あと208枚です
# あと207枚です
# あと206枚です
# あと205枚です
# あと204枚です
# あと203枚です
# あと202枚です
# あと201枚です
# あと200枚です
# あと199枚です
# あと198枚です
# あと197枚です
# あと196枚です
# あと195枚です
# あと194枚です
# あと193枚です
# あと192枚です
# あと191枚です
# あと190枚です
# あと189枚です
# あと188枚です
# あと187枚です
# あと186枚です
# あと185枚です
# あと184枚です
# あと183枚です
# あと182枚です
# あと181枚です
# あと180枚です
# あと179枚です
# あと178枚です
# あと177枚です
# あと176枚です
# あと175枚です
# あと174枚です
# あと173枚です
# あと172枚です
# あと171枚です
# あと170枚です
# あと169枚です
# あと168枚です
# あと167枚です
# あと166枚です
# あと165枚です
# あと164枚です
# あと163枚です
# あと162枚です
# あと161枚です
# あと160枚です
# あと159枚です
# あと158枚です
# あと157枚です
# あと156枚です
# あと155枚です
# あと154枚です
# あと153枚です
# あと152枚です
# あと151枚です
# あと150枚です
# あと149枚です
# あと148枚です
# あと147枚です
# あと146枚です
# あと145枚です
# あと144枚です
# あと143枚です
# あと142枚です
# あと141枚です
# あと140枚です
# あと139枚です
# あと138枚です
# あと137枚です
# あと136枚です
# あと135枚です
# あと134枚です
# あと133枚です
# あと132枚です
# あと131枚です
# あと130枚です
# あと129枚です
# あと128枚です
# あと127枚です
# あと126枚です
# あと125枚です
# あと124枚です
# あと123枚です
# あと122枚です
# あと121枚です
# あと120枚です
# あと119枚です
# あと118枚です
# あと117枚です
# あと116枚です
# あと115枚です
# あと114枚です
# あと113枚です
# あと112枚です
# あと111枚です
# あと110枚です
# あと109枚です
# あと108枚です
# あと107枚です
# あと106枚です
# あと105枚です
# あと104枚です
# あと103枚です
# あと102枚です
# あと101枚です
# あと100枚です
# あと99枚です
# あと98枚です
# あと97枚です
# あと96枚です
# あと95枚です
# あと94枚です
# あと93枚です
# あと92枚です
# あと91枚です
# あと90枚です
# あと89枚です
# あと88枚です
# あと87枚です
# あと86枚です
# あと85枚です
# あと84枚です
# あと83枚です
# あと82枚です
# あと81枚です
# あと80枚です
# あと79枚です
# あと78枚です
# あと77枚です
# あと76枚です
# あと75枚です
# あと74枚です
# あと73枚です
# あと72枚です
# あと71枚です
# あと70枚です
# あと69枚です
# あと68枚です
# あと67枚です
# あと66枚です
# あと65枚です
# あと64枚です
# あと63枚です
# あと62枚です
# あと61枚です
# あと60枚です
# あと59枚です
# あと58枚です
# あと57枚です
# あと56枚です
# あと55枚です
# あと54枚です
# あと53枚です
# あと52枚です
# あと51枚です
# あと50枚です
# あと49枚です
# あと48枚です
# あと47枚です
# あと46枚です
# あと45枚です
# あと44枚です
# あと43枚です
# あと42枚です
# あと41枚です
# あと40枚です
# あと39枚です
# あと38枚です
# あと37枚です
# あと36枚です
# あと35枚です
# あと34枚です
# あと33枚です
# あと32枚です
# あと31枚です
# あと30枚です
# あと29枚です
# あと28枚です
# あと27枚です
# あと26枚です
# あと25枚です
# あと24枚です
# あと23枚です
# あと22枚です
# あと21枚です
# あと20枚です
# あと19枚です
# あと18枚です
# あと17枚です
# あと16枚です
# あと15枚です
# あと14枚です
# あと13枚です
# あと12枚です
# あと11枚です
# あと10枚です
# あと9枚です
# あと8枚です
# あと7枚です
# あと6枚です
# あと5枚です
# あと4枚です
# あと3枚です
# あと2枚です
# あと1枚です
